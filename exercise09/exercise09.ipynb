# %% [markdown]
# # Laboratorio di simulazione numerica

# %%
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['text.usetex'] = True
import numpy as np
import math
import string

colors = ["firebrick", "limegreen", "royalblue", "darkorange"]

# %% [markdown]
# #### Exercise 09.1

# %% [markdown]
# ##### Cities on a circle

# %%
gen, best_fit_length = np.loadtxt("best_fit_length_circle.dat", unpack = True)
gen, avg_best_length = np.loadtxt("averaged_best_length_circle.dat", unpack = True)
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 5))
axes = axes.flatten()

axes[0].plot(best_fit_length)
axes[0].set_title("Length of the best path")
axes[0].set_xlabel("Generation")
axes[0].set_ylabel("Length")
axes[0].grid(True)

axes[1].plot(avg_best_length)
axes[1].set_title("Average length of the best half of the population")
axes[1].set_xlabel("Generation")
axes[1].set_ylabel("Length")
axes[1].grid(True)

plt.show()

# %% [markdown]
# ##### Cities in a square

# %%
gen, best_fit_length = np.loadtxt("best_fit_length_square.dat", unpack = True)
gen, avg_best_length = np.loadtxt("averaged_best_length_square.dat", unpack = True)
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (12, 5))
axes = axes.flatten()

axes[0].plot(best_fit_length)
axes[0].set_title("Length of the best path")
axes[0].set_xlabel("Generation")
axes[0].set_ylabel("Length")
axes[0].grid(True)

axes[1].plot(avg_best_length)
axes[1].set_title("Average length of the best half of the population")
axes[1].set_xlabel("Generation")
axes[1].set_ylabel("Length")
axes[1].grid(True)

plt.show()
